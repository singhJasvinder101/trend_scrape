# %%
from flask import Flask, jsonify
from scraper.twitter_selenium import TwitterScraper 
import traceback

app = Flask(__name__)

@app.route('/')
def hello_world():
    return "Hello World!"

@app.route('/trending', methods=['POST'])
def get_trending():
    try:
        scraper = TwitterScraper()
        result = scraper.scrape_twitter() 
        
        trending_data = {
            'unique_id': result['unique_id'],
            'date_time': result['date_time'],
            'ip_address': result['ip_address'],
            'trends': result['trends']
        }
        
        return jsonify(trending_data), 200 
    except Exception as e:
        error_message = f"Error occurred during scraping: {str(e)}"
        print(traceback.format_exc())
        return jsonify({'error': error_message}), 500

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from flask import Flask, jsonify
# ----> 2 from scraper.twitter_selenium import TwitterScraper
#       3 import traceback
#       5 app = Flask(__name__)
#
# File E:\Python Full\twitter_selenium\scraper\twitter_selenium.py:238
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 15,
#       6    "id": "a795f713-a7ac-4c74-88fc-cbcd82d95e3f",
#       7    "metadata": {},
#       8    "outputs": [
#       9     {
#      10      "name": "stdout",
#      11      "output_type": "stream",
#      12      "text": [
#      13       " * Serving Flask app '__main__'\n",
#      14       " * Debug mode: on\n"
#      15      ]
#      16     },
#      17     {
#      18      "name": "stderr",
#      19      "output_type": "stream",
#      20      "text": [
#      21       "WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.\n",
#      22       " * Running on http://127.0.0.1:5000\n",
#      23       "Press CTRL+C to quit\n",
#      24       " * Restarting with stat\n"
#      25      ]
#      26     },
#      27     {
#      28      "ename": "SystemExit",
#      29      "evalue": "1",
#      30      "output_type": "error",
#      31      "traceback": [
#      32       "An exception has occurred, use %tb to see the full traceback.\n",
#      33       "\u001bSystemExit\u001b\u001b:\u001b 1\n"
#      34      ]
#      35     }
#      36    ],
#      37    "source": [
#      38     "# twitter_scraper.py\n",
#      39     "import os\n",
#      40     "import uuid\n",
#      41     "from datetime import datetime\n",
#      42     "from dotenv import load_dotenv\n",
#      43     "from selenium import webdriver\n",
#      44     "from selenium.webdriver.common.by import By\n",
#      45     "from selenium.webdriver.support.ui import WebDriverWait\n",
#      46     "from selenium.webdriver.support import expected_conditions as EC\n",
#      47     "from selenium.common.exceptions import TimeoutException\n",
#      48     "from pymongo import MongoClient\n",
#      49     "from flask import Flask, render_template, jsonify\n",
#      50     "import random\n",
#      51     "from selenium.webdriver.chrome.options import Options\n",
#      52     "\n",
#      53     "# Load environment variables\n",
#      54     "load_dotenv()\n",
#      55     "\n",
#      56     "# using proxymesh proxy\n",
#      57     "proxy = {\n",
#      58     "  'http': 'http://us-ca.proxymesh.com:31280',\n",
#      59     "  'https': 'http://us-ca.proxymesh.com:31280'\n",
#      60     "}\n",
#      61     "\n",
#      62     "from fake_useragent import UserAgent\n",
#      63     "\n",
#      64     "# Configuration\n",
#      65     "# TWITTER_EMAIL = os.getenv('TWITTER_EMAIL')\n",
#      66     "# TWITTER_PASSWORD = os.getenv('TWITTER_PASSWORD')\n",
#      67     "# PROXYMESH_AUTH = os.getenv('PROXYMESH_AUTH')\n",
#      68     "# MONGO_URI = os.getenv('MONGO_URI', 'mongodb://localhost:27017/')\n",
#      69     "# PROXY_LIST = os.getenv('PROXY_LIST', '').split(',')\n",
#      70     "\n",
#      71     "TWITTER_EMAIL = \"jasvindersingh3593@gmail.com\"\n",
#      72     "TWITTER_PASSWORD = \"Karan234@\"\n",
#      73     "MONGO_URI = 'mongodb://localhost:27017/'\n",
#      74     "\n",
#      75     "# Flask app initialization\n",
#      76     "app = Flask(__name__)\n",
#      77     "\n",
#      78     "class TwitterScraper:\n",
#      79     "    def __init__(self):\n",
#      80     "        self.mongo_client = MongoClient(MONGO_URI)\n",
#      81     "        self.db = self.mongo_client['twitter_trends']\n",
#      82     "        self.collection = self.db['trending_topics']\n",
#      83     "\n",
#      84     "    def setup_driver(self):\n",
#      85     "        user_agent = UserAgent().random\n",
#      86     "        \n",
#      87     "        chrome_options = Options()\n",
#      88     "        chrome_options.add_argument('--headless')\n",
#      89     "        chrome_options.add_argument('--no-sandbox')\n",
#      90     "        chrome_options.add_argument('--disable-dev-shm-usage')\n",
#      91     "        chrome_options.add_argument(f'user-agent={user_agent}') \n",
#      92     "        \n",
#      93     "        return webdriver.Chrome(options=chrome_options)\n",
#      94     "\n",
#      95     "\n",
#      96     "    def login_to_twitter(self, driver):\n",
#      97     "        \"\"\"Handle Twitter login process\"\"\"\n",
#      98     "        try:\n",
#      99     "            driver.get('https://twitter.com/login')\n",
#     100     "            wait = WebDriverWait(driver, 10)\n",
#     101     "            \n",
#     102     "            # Enter email\n",
#     103     "            email_field = wait.until(EC.presence_of_element_located((By.NAME, \"text\")))\n",
#     104     "            email_field.send_keys(TWITTER_EMAIL)\n",
#     105     "            driver.find_element(By.XPATH, \"//span[text()='Next']\").click()\n",
#     106     "            \n",
#     107     "            # Enter password\n",
#     108     "            password_field = wait.until(EC.presence_of_element_located((By.NAME, \"password\")))\n",
#     109     "            password_field.send_keys(TWITTER_PASSWORD)\n",
#     110     "            driver.find_element(By.XPATH, \"//span[text()='Log in']\").click()\n",
#     111     "            \n",
#     112     "            # Wait for login completion\n",
#     113     "            wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, \"[data-testid='primaryColumn']\")))\n",
#     114     "            \n",
#     115     "        except TimeoutException as e:\n",
#     116     "            raise Exception(f\"Login failed: {str(e)}\")\n",
#     117     "\n",
#     118     "    def get_trending_topics(self, driver):\n",
#     119     "        \"\"\"Extract trending topics from Twitter homepage\"\"\"\n",
#     120     "        try:\n",
#     121     "            wait = WebDriverWait(driver, 10)\n",
#     122     "            trending_section = wait.until(EC.presence_of_element_located(\n",
#     123     "                (By.CSS_SELECTOR, \"[data-testid='trend']\")))\n",
#     124     "            \n",
#     125     "            trends = driver.find_elements(By.CSS_SELECTOR, \"[data-testid='trend']\")\n",
#     126     "            return [trend.text.split('\\n')[0] for trend in trends[:5]]\n",
#     127     "            \n",
#     128     "        except TimeoutException as e:\n",
#     129     "            raise Exception(f\"Failed to fetch trending topics: {str(e)}\")\n",
#     130     "\n",
#     131     "    def store_trends(self, trends, ip_address):\n",
#     132     "        \"\"\"Store trending topics in MongoDB\"\"\"\n",
#     133     "        document = {\n",
#     134     "            'unique_id': str(uuid.uuid4()),\n",
#     135     "            'trend1': trends[0] if len(trends) > 0 else None,\n",
#     136     "            'trend2': trends[1] if len(trends) > 1 else None,\n",
#     137     "            'trend3': trends[2] if len(trends) > 2 else None,\n",
#     138     "            'trend4': trends[3] if len(trends) > 3 else None,\n",
#     139     "            'trend5': trends[4] if len(trends) > 4 else None,\n",
#     140     "            'date_time': datetime.now(),\n",
#     141     "            'ip_address': ip_address\n",
#     142     "        }\n",
#     143     "        \n",
#     144     "        return self.collection.insert_one(document).inserted_id\n",
#     145     "\n",
#     146     "    def fetch_latest_trends(self):\n",
#     147     "        \"\"\"Retrieve the most recent trends from MongoDB\"\"\"\n",
#     148     "        return self.collection.find_one(\n",
#     149     "            sort=[('date_time', -1)]\n",
#     150     "        )\n",
#     151     "\n",
#     152     "    def scrape_twitter(self):\n",
#     153     "        \"\"\"Main scraping function\"\"\"\n",
#     154     "        driver = None\n",
#     155     "        try:\n",
#     156     "            driver = self.setup_driver()\n",
#     157     "            self.login_to_twitter(driver)\n",
#     158     "            trends = self.get_trending_topics(driver)\n",
#     159     "            ip_address = driver.execute_script(\"return fetch('https://api.ipify.org?format=json').then(r => r.json())\")['ip']\n",
#     160     "            inserted_id = self.store_trends(trends, ip_address)\n",
#     161     "            return self.collection.find_one({'_id': inserted_id})\n",
#     162     "            \n",
#     163     "        except Exception as e:\n",
#     164     "            raise Exception(f\"Scraping failed: {str(e)}\")\n",
#     165     "            \n",
#     166     "        finally:\n",
#     167     "            if driver:\n",
#     168     "                driver.quit()\n",
#     169     "\n",
#     170     "# Flask routes\n",
#     171     "@app.route('/')\n",
#     172     "def index():\n",
#     173     "    return render_template('index.html')\n",
#     174     "\n",
#     175     "@app.route('/fetch-trends')\n",
#     176     "def fetch_trends():\n",
#     177     "    try:\n",
#     178     "        scraper = TwitterScraper()\n",
#     179     "        result = scraper.scrape_twitter()\n",
#     180     "        return jsonify({\n",
#     181     "            'status': 'success',\n",
#     182     "            'data': {\n",
#     183     "                'unique_id': result['unique_id'],\n",
#     184     "                'trends': [\n",
#     185     "                    result['trend1'],\n",
#     186     "                    result['trend2'],   \n",
#     187     "                    result['trend3'],\n",
#     188     "                    result['trend4'],\n",
#     189     "                    result['trend5']\n",
#     190     "                ],\n",
#     191     "                'date_time': result['date_time'].strftime('%Y-%m-%d %H:%M:%S'),\n",
#     192     "                'ip_address': result['ip_address']\n",
#     193     "            }\n",
#     194     "        })\n",
#     195     "    except Exception as e:\n",
#     196     "        return jsonify({\n",
#     197     "            'status': 'error',\n",
#     198     "            'message': str(e)\n",
#     199     "        }), 500\n",
#     200     "\n",
#     201     "if __name__ == '__main__':\n",
#     202     "    app.run(debug=True)"
#     203    ]
#     204   },
#     205   {
#     206    "cell_type": "code",
#     207    "execution_count": 13,
#     208    "id": "667a08e3-ec11-4f4b-ae97-e4563afe73fc",
#     209    "metadata": {},
#     210    "outputs": [
#     211     {
#     212      "name": "stdout",
#     213      "output_type": "stream",
#     214      "text": [
#     215       "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36\n"
#     216      ]
#     217     }
#     218    ],
#     219    "source": [
#     220     "import requests\n",
#     221     "from fake_useragent import UserAgent\n",
#     222     "\n",
#     223     "def get_ip_address():\n",
#     224     "    try:\n",
#     225     "        user_agent = UserAgent().random\n",
#     226     "        return user_agent\n",
#     227     "    except requests.RequestException as e:\n",
#     228     "        return 'Unknown'\n",
#     229     "\n",
#     230     "# Usage\n",
#     231     "ip_address = get_ip_address()\n",
#     232     "\n",
#     233     "print(ip_address)\n"
#     234    ]
#     235   },
#     236   {
#     237    "cell_type": "code",
# --> 238    "execution_count": null,
#     239    "id": "c16d4844-a424-4cf0-a6e5-a78037aeee4c",
#     240    "metadata": {},
#     241    "outputs": [],
#     242    "source": []
#     243   }
#     244  ],
#     245  "metadata": {
#     246   "kernelspec": {
#     247    "display_name": "Python 3",
#     248    "language": "python",
#     249    "name": "python3"
#     250   },
#     251   "language_info": {
#     252    "codemirror_mode": {
#     253     "name": "ipython",
#     254     "version": 3
#     255    },
#     256    "file_extension": ".py",
#     257    "mimetype": "text/x-python",
#     258    "name": "python",
#     259    "nbconvert_exporter": "python",
#     260    "pygments_lexer": "ipython3",
#     261    "version": "3.12.4"
#     262   }
#     263  },
#     264  "nbformat": 4,
#     265  "nbformat_minor": 5
#     266 }
#
# NameError: name 'null' is not defined
